# %% [markdown]
# # Column dtypes
# V dnesonom videu sa budeme venovat praci so stlpcami roznych datovych typov.
# V druhej casti videa sa budeme venovat praci s NaN hodnotami
#
# Link na [video](https://youtu.be/9Oy4IZh9z04)

# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv("dataset/train.csv")
df.shape
# Out:
# (1460, 81)

# %%
# Rychlejsi prehlad pocetnosti datovych typov stlpcov
df.dtypes.value_counts()
# Out:
# object     43
# int64      35
# float64     3
# dtype: int64

# %%
# Filtrovanie ciselnych stlpcov
df_numeric = df.loc[:, (df.dtypes == np.int64) | (df.dtypes == np.float64)]

# %%
# Filtrovanie textovych stlpcov
df_object = df.loc[:, df.dtypes == np.object]
df_object
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %% [markdown]
# # Nans
# Nan hodnoty su takzvane prazdne hodnoty

# %%
# Prikaz zisti ci sa v stlpci nachadza aspon jedna NaN hodnota
any(df.Alley.notna())
# Out:
# True

# %%
# Prikaz zisti ci sa v stlpci nachadzaju len NaN hodnoty 
all(df.Alley.notna())
# Out:
# False

# %%
# Pocetnosti hodnot stlpca (v sucte menej ako vsetky hodnoty v stlpce preto viem ze su tam NaN hodnoty)
df.Alley.value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %% [markdown]
# ## 1. Mazanie stlpcov s NaN hodnotami

# %%
# df.dropna()
# df.dropna(how="all") # Mazanie riadkov kde su len NaN hodnoty 
# df.dropna(how="all", axis=1) # To iste pre stlpce
df.dropna(axis=1) # Mazanie stlpca kde je aspon jedna hodnota
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
# Mazanie riadkov kde su NaN hodnoty na zaklade dvoch stlpcov
target_columns = df.loc[:, ["Alley" , "Fence"]]
row_mask = target_columns.notna().apply(any, axis=1) # maska ktoru aplikujem v locu
df.loc[row_mask, :]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# 19      20          20       RL         70.0     7560   Pave   NaN      Reg
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1438  1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1448  1449          50       RL         70.0    11767   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
# ...

# %%
# Nazvy ciselnych stlpcov s aspon jednou NaN hodnotou
df.loc[:, (df.dtypes == np.int64) | (df.dtypes == np.float64)].isna().apply(any).index.values
# Out:
# array(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'], dtype=object)

# %% [markdown]
# ## 2. Nahradzovanie NaN hodnot

# %%
any(df.GarageYrBlt.isna())
# Out:
# True

# %%
df.loc[df.GarageYrBlt.isna(), :]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 39      40          90       RL         65.0     6040   Pave   NaN      Reg
# 48      49         190       RM         33.0     4456   Pave   NaN      Reg
# 78      79          90       RL         72.0    10778   Pave   NaN      Reg
# 88      89          50  C (all)        105.0     8470   Pave   NaN      IR1
# 89      90          20       RL         60.0     8070   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 1407  1408          20       RL          NaN     8780   Pave   NaN      IR1
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
#
# ...

# %%
# Takto nahradim NaN hodnotu v stlpci priemerom
df.loc[df.GarageYrBlt.isna(), "GarageYrBlt"] = df.GarageYrBlt.mean()

# %%
df.GarageYrBlt.mean()
df.GarageYrBlt.median()
df.GarageYrBlt.min()
df.GarageYrBlt.max()
# Out:
# 2010.0

# %%
any(df.GarageYrBlt.isna())
# Out:
# False

# %%
# Takto nahradim NaN hodnoty najcastejsie sa opakujucou hodnotou
df.loc[df.Alley.isna(), "Alley"] = df.Alley.value_counts().index.values[0]

# %%
df.Alley
# Out:
# 0       Grvl
# 1       Grvl
# 2       Grvl
# 3       Grvl
# 4       Grvl
#         ...
# 1455    Grvl
# 1456    Grvl
# 1457    Grvl
# 1458    Grvl
# 1459    Grvl
# Name: Alley, Length: 1460, dtype: object
