# %% [markdown]
# # Ukážka použitia jupyter notebooku pri vykresľovaní grafov
# Na spustenie bunky je možné použiť nasledujúce skratky
# - __ctrl + enter__ spustí aktuálnu bunku
# - __shift + enter__ spustí aktuálnu bunku a presunie sa na ďalšiu. Ak nasledujúca bunka neexistuje vytvorí novú

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Pomocou príkazu</br>
# __%matplotlib inline__</br>
# vieme zabudovať grafy priamo do jupyter notebooku

# %%
df = pd.read_csv("data/iris.csv") # read_csv sluzi na nacitanie dat z csv suboru do pandas dataframu, budeme sa venovat neskor

# %%
df.tail() # tail vypisuje poslednych 5 riadkov dataframu
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.plot() # Ukazka zabudovaneho grtafu, na obrazku vidiet linechart, ktory si vysvetlime neskor
# Out:
# <AxesSubplot:>

# %%
df.sepal_length.hist(bins=20) # ukazka zabudovaneho histogramu, tento diagram si vysvetlime neskor
# Out:
# <AxesSubplot:>

# %%
df.sepal_length.hist(bins=50)
# Out:
# <AxesSubplot:>
