# %% [markdown]
# # Pridavanie stlpcov a riadkov
# Okrem selekcie nam pandas umoznuje aj pridavat nove hodnoty do nasho dataframu. V dnesnej lekcii si ukazeme ako na to.
#
# Link na [video](https://youtu.be/tI2eimVKO3M)

# %%
import pandas as pd 

df = pd.read_csv("dataset/train.csv")

# %%
# Pomocou = viem priradit jednu hodnotu
df.MSZoning = 1
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60         1         65.0     8450   Pave   NaN      Reg
# 1   2          20         1         80.0     9600   Pave   NaN      Reg
# 2   3          60         1         68.0    11250   Pave   NaN      IR1
# 3   4          70         1         60.0     9550   Pave   NaN      IR1
# 4   5          60         1         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Alebo viem priradit zoskupenie, ktore ma rovnaku velkost napriklad pole 
df.MSZoning = list(range(0,1460))
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60         0         65.0     8450   Pave   NaN      Reg
# 1   2          20         1         80.0     9600   Pave   NaN      Reg
# 2   3          60         2         68.0    11250   Pave   NaN      IR1
# 3   4          70         3         60.0     9550   Pave   NaN      IR1
# 4   5          60         4         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Alebo viem priradit Series
df.MSZoning = pd.Series(list(range(0,1460)))
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60         0         65.0     8450   Pave   NaN      Reg
# 1   2          20         1         80.0     9600   Pave   NaN      Reg
# 2   3          60         2         68.0    11250   Pave   NaN      IR1
# 3   4          70         3         60.0     9550   Pave   NaN      IR1
# 4   5          60         4         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Pozor na zly rozmer 
# Pri zlom rozmere v Series priradi Nan
df.MSZoning = pd.Series(list(range(0,1459)))
df.tail() # tail je opak head
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60    1455.0         62.0     7917   Pave   NaN      Reg
# 1456  1457          20    1456.0         85.0    13175   Pave   NaN      Reg
# 1457  1458          70    1457.0         66.0     9042   Pave   NaN      Reg
# 1458  1459          20    1458.0         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       NaN         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
# ...

# %%
print(df.iloc[1459]["MSZoning"])
type(df.iloc[1459]["MSZoning"])
# Out:
# nan
# numpy.float64

# %%
# POZOR ak priradzujem zoskupenie ine ako pandas series s roznym rozmermi dostanem chybu 
df.MSZoning = list(range(0,1459))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-765c6a0628c2> in <module>
#       1 # POZOR ak priradzujem zoskupenie ine ako pandas series s roznym rozmermi dostanem chybu
# ----> 2 df.MSZoning = list(range(0,1459))
#
# c:\users\michal_hucko\documents\tutorials\data_analytics\env\analytics\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5166                     object.__setattr__(self, name, value)
#    5167                 elif name in self._info_axis:
# -> 5168                     self[name] = value
#    5169                 else:
#    5170                     object.__setattr__(self, name, value)
#
# c:\users\michal_hucko\documents\tutorials\data_analytics\env\analytics\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# ...

# %% [markdown]
# # Pandas copy vs view
# - ked pracujem s loc a iloc tak pracujem s __view__ alebo s referenciou do povodneho dataframu ked zmenim nieco cez iloc menim aj povodny df.
# - toto neplati vzdy pri pristupe cez hranate zatvorky. Tieto v niektorych pripadoch vracaju __copy__ co su vlastne skopirovane data z vyberu a teda su ako keby novy dataframe.

# %%
# Nulovanie cez hranate zatvorky a ich retazenie sposobuje warning !!! 
# Warning hovory ze niekedy sa sprava pristup cez zatvorky ako view a niekedy nie a treba si dat na to pozor
df[df.SalePrice > 181500].SalePrice = 0 # toto je zly pristup
# Out:
# c:\users\michal_hucko\documents\tutorials\data_analytics\env\analytics\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
# Hodnoty sa vsak nezmenili lebo sme pracovali s kopiou nie s view. TOTO JE ZLE PRETO RADSEJ POUZIVAME loc a iloc!!!
df.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       0.0         65.0     8450   Pave   NaN      Reg
# 1   2          20       1.0         80.0     9600   Pave   NaN      Reg
# 2   3          60       2.0         68.0    11250   Pave   NaN      IR1
# 3   4          70       3.0         60.0     9550   Pave   NaN      IR1
# 4   5          60       4.0         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Nepomoze ani ked to oddelime na viac prikazov
temp_df = df[df.SalePrice > 181500] # lebo toto je uz kopia a nie je to view.
temp_df.SalePrice = 0
df.head()
# Out:
# c:\users\michal_hucko\documents\tutorials\data_analytics\env\analytics\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       0.0         65.0     8450   Pave   NaN      Reg
# 1   2          20       1.0         80.0     9600   Pave   NaN      Reg
# 2   3          60       2.0         68.0    11250   Pave   NaN      IR1
# 3   4          70       3.0         60.0     9550   Pave   NaN      IR1
# 4   5          60       4.0         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# ...

# %%
# MAGIC, ked zmenime poradie Voilà, zrazu to funguje. LOOOL 
df.SalePrice[df.SalePrice > 181500] = 0
df.head()
# Out:
# <ipython-input-11-74fe1f2c5d92>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.SalePrice[df.SalePrice > 181500] = 0
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       0.0         65.0     8450   Pave   NaN      Reg
# 1   2          20       1.0         80.0     9600   Pave   NaN      Reg
# 2   3          60       2.0         68.0    11250   Pave   NaN      IR1
# 3   4          70       3.0         60.0     9550   Pave   NaN      IR1
# 4   5          60       4.0         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# ...

# %%
# Znovu nacitat data
df = pd.read_csv("dataset/train.csv")

# Riesenie vsetkeho je pouzivat loc iloc lebo vzdy vracia view
df.loc[df.SalePrice > 181500, "SalePrice"] = 10
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# Chainovanie loc a iloc nie je dobre. Efektivnejsie je mat co najmenej loc iloc
df.loc[df.SalePrice > 181500, :].loc[df.MSSubClass > 30, :] # toto je zle 
df.loc[(df.SalePrice > 181500) & (df.MSSubClass > 30), :] # toto je cool
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...
